# %% [markdown]
# 13/03/2026
#
# #Pertemuan Selasa
#
# Pembahasan mengenai PKM,
# Para siswa di harap dapat mengikuti seminar proposal tugas akhir.
# Ambil mappen yang srek dengan diri kalian sendiri, pelajari membuat jurnal sinta 1.
#
# <hr>
#
# Variable:
# - Kromosom
# - penggabungan gen agar mendapatkan gen yang terbaik
# - kandidat kromosom
# - fitness function
# - algoritma genetika
# - operasi algoritma genetika
# - Crossover
# - Mutasi
# - Turnament Selection
# -
#
# Fungsi Fitness adalah bagaimana supaya kita bisa mencari sesuatu secara maksimalnya, atau fungsi terbaik untuk traveling salashman problem
#
# Tugas (waktu 2 minggu)
# 1 kelompok 4 orang
# cari studi kasus untuk penyelesaian algoritma genetika
# kasusnya bukan fungsi x2
# Bisa kasus Kota, Jadwal, TSP,
# jika sama sama tsp datanya wajib sama namun metodenya berbeda
#
# bisa pakai Roulete Wheel atau Rank selection, Single point Crossover, Double point Crossover
#
# yang dinilai :
# perhitungan manual -------------------------------------------------
# programnya ada 2 (perhitungan manual atau elitism)                 |------ << 1 MINGGU
# elitism  -----------------------------------------------------------
#
# analisa : Memabandingkan dengan kelompok lain -------------- <<< 1 MINGGU
