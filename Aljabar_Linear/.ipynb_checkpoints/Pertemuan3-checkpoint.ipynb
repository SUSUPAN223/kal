# %% [markdown]
# # Pertemuan 3 (26/022026/)
#
#
#
# B = matrix([[1,-1,-1],[1,-2,-4]])
# C = B.add_multiple_of_row(1,0,-1)
# D = B.rescale_row(1,-1)
#
# B
#
# ***
#
# B = matrix([[1,1,1,3],[2,2,1,5],[1,1,4,6]])
# B.add_multiple_of_row(1,0,-2)
# B.add_multiple_of_row(2,0,-1)
# B.add_multiple_of_row(1,0,1/3)
#
# B
#
#
# Tugas :
# Membuat contoh penyelesaian sistem persamaan linear 3 variable dan 4 variable dengan menggunakan eliminasi gaussian
# Pengerjaan pake sage dari bapaknya, lalu hasilnya taruh di jupyter book
# Jangan lupa di onlinekan githubnya jaga jaga untuk kedepannya
